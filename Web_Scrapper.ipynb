# %% [markdown]
# <a href="https://colab.research.google.com/github/Pawan61473/DataScience/blob/main/Web_Scrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests, openpyxl

# %%
url = "https://www.imdb.com/list/ls009997493/"

source = requests.get(url)

# %%
soup = BeautifulSoup(source.text, "html")

# %%
movies = soup.find('div', class_="lister-list").find_all('div', class_='lister-item mode-detail')
len(movies)
# Out:
# 100

# %%
Ranks = []
Names = []
Years = []
Ratings = []
for movie in movies:
  rank = movie.find('div', class_= 'lister-item-content').h3.find('span', class_= "lister-item-index unbold text-primary").text
  Ranks.append(rank)
  name = movie.find('div', class_='lister-item-content').h3.a.text
  Names.append(name)
  year = movie.find('div', class_= 'lister-item-content').h3.find('span', class_= "lister-item-year text-muted unbold").text
  Years.append(year)
  rating = movie.find('div', class_= 'lister-item-content').find('div', class_= "ipl-rating-widget").find('div',class_="ipl-rating-star small").find('span', class_="ipl-rating-star__rating").text
  Ratings.append(rating)

# %%
import pandas as pd
final_data = pd.DataFrame({"Rank":Ranks,"Name":Names,"Year":Years,"Rating":Ratings})

# %%
final_data
# Out:
#     Rank                 Name    Year Rating
# 0     1.      Rang De Basanti  (2006)    8.1
# 1     2.             3 Idiots  (2009)    8.4
# 2     3.  Like Stars on Earth  (2007)    8.3
# 3     4.       Dil Chahta Hai  (2001)    8.1
# 4     5.               Swades  (2004)    8.2
# ..   ...                  ...     ...    ...
# 95   96.          Wake Up Sid  (2009)    7.6
# 96   97.             Rangeela  (1995)    7.4
# 97   98.    The Chess Players  (1977)    7.5
# 98   99.   Pyaar Ka Punchnama  (2011)    7.6
# 99  100.        Ek Hasina Thi  (2004)    7.5
#
# [100 rows x 4 columns]

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
final_data.to_excel('/content/drive/My Drive/Top Bollywood Movies.xlsx',)
